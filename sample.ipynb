# %%
x = ['andorra','comoros','french_guiana','french_polynesia','french_southern_territories','guadeloupe','martinique','mayotte','monaco','new_caledonia','reunion','saint_barthelemy','saint_martin_french_part','saint_pierre_and_miquelon','vanuatu','wallis_and_futuna','israel','malta','rcis_region','aland_islands','bouvet_island','faroe_islands','greenland','iceland','svalbard_and_jan_mayen','liechtenstein','zimbabwe','zambia','western_sahara','uganda','tunisia','togo','tanzania_united_republic_of','sudan','south_sudan','somalia','sierra_leone','seychelles','senegal','sao_tome_and_principe','rwanda','nigeria','niger','namibia','mozambique','morocco','mauritius','mauritania','mali','malawi','madagascar','libya','liberia','kenya','guinea_bissau','guinea','ghana','gambia','gabon','ethiopia','eritrea','equatorial_guinea','djibouti','cote_divoire','congo_the_democratic_republic_of_the','congo','chad','central_african_republic','cape_verde','cameroon','burundi','burkina_faso','botswana','benin','angola','algeria','middle_east_pakistan','turkey','british_indian_ocean_territory','falkland_islands_malvinas','gibraltar','guernsey','isle_of_man','jersey','pitcairn','saint_helena_ascension_and_tristan_da_cunha','south_georgia_and_the_south_sandwich_islands','albania','bosnia_and_herzegovina','croatia','macedonia_the_former_yugoslav_republic_of','moldova_republic_of','montenegro','romania','slovenia']
type(x)
# Out:
# list

# %%
print(*x, sep = "\n")
# Out:
# andorra
# comoros
# french_guiana
# french_polynesia
# french_southern_territories
# guadeloupe
# martinique
# mayotte
# monaco
# new_caledonia
# reunion
# saint_barthelemy
# saint_martin_french_part
# saint_pierre_and_miquelon
# vanuatu
# wallis_and_futuna
# israel
# malta
# rcis_region
# aland_islands
# bouvet_island
# faroe_islands
# greenland
# iceland
# svalbard_and_jan_mayen
# liechtenstein
# zimbabwe
# zambia
# western_sahara
# uganda
# tunisia
# togo
# tanzania_united_republic_of
# sudan
# south_sudan
# somalia
# sierra_leone
# seychelles
# senegal
# sao_tome_and_principe
# rwanda
# nigeria
# niger
# namibia
# mozambique
# morocco
# mauritius
# mauritania
# mali
# malawi
# madagascar
# libya
# liberia
# kenya
# guinea_bissau
# guinea
# ghana
# gambia
# gabon
# ethiopia
# eritrea
# equatorial_guinea
# djibouti
# cote_divoire
# congo_the_democratic_republic_of_the
# congo
# chad
# central_african_republic
# cape_verde
# cameroon
# burundi
# burkina_faso
# botswana
# benin
# ...

# %%
x.sort()
print(*x, sep = "\n")
# Out:
# aland_islands
# albania
# algeria
# andorra
# angola
# benin
# bosnia_and_herzegovina
# botswana
# bouvet_island
# british_indian_ocean_territory
# burkina_faso
# burundi
# cameroon
# cape_verde
# central_african_republic
# chad
# comoros
# congo
# congo_the_democratic_republic_of_the
# cote_divoire
# croatia
# djibouti
# equatorial_guinea
# eritrea
# ethiopia
# falkland_islands_malvinas
# faroe_islands
# french_guiana
# french_polynesia
# french_southern_territories
# gabon
# gambia
# ghana
# gibraltar
# greenland
# guadeloupe
# guernsey
# guinea
# guinea_bissau
# iceland
# isle_of_man
# israel
# jersey
# kenya
# liberia
# libya
# liechtenstein
# macedonia_the_former_yugoslav_republic_of
# madagascar
# malawi
# mali
# malta
# martinique
# mauritania
# mauritius
# mayotte
# middle_east_pakistan
# moldova_republic_of
# monaco
# montenegro
# morocco
# mozambique
# namibia
# new_caledonia
# niger
# nigeria
# pitcairn
# rcis_region
# reunion
# romania
# rwanda
# saint_barthelemy
# ...
